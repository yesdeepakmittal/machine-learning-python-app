# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
titanic_train = pd.read_csv('Downloads/train.csv')
titanic_test = pd.read_csv('Downloads/test.csv')

# %%
titanic_train.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
titanic_test.head().T              #transpose
# Out:
#                             0                                 1  \
# PassengerId               892                               893
# Pclass                      3                                 3
# Name         Kelly, Mr. James  Wilkes, Mrs. James (Ellen Needs)
# Sex                      male                            female
# Age                      34.5                                47
# SibSp                       0                                 1
# Parch                       0                                 0
# Ticket                 330911                            363272
# Fare                   7.8292                                 7
# Cabin                     NaN                               NaN
# Embarked                    Q                                 S
#
#                                      2                 3  \
# PassengerId                        894               895
# Pclass                               2                 3
# ...

# %%
titanic_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
titanic_train.hist(bins=20,figsize=(10,10),grid=True,color='g')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000217B9AED6A0>,
# ...
#       dtype=object)

# %%
plt.scatter(x=titanic_train['Age'],y=titanic_train['Pclass'],marker='+')

# %%
titanic_train.groupby(titanic_train['Cabin'].isnull()).mean()
# Out:
#        PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Cabin
# False   455.401961  0.666667  1.196078  35.829297  0.441176  0.436275
# True    443.208151  0.299854  2.639010  27.555293  0.547307  0.365357
#
#             Fare
# Cabin
# False  76.141504
# True   19.157325

# %%
titanic_train.pivot_table('Survived',index='Pclass',columns='Embarked',aggfunc='count')
# Out:
# Embarked   C   Q    S
# Pclass
# 1         85   2  127
# 2         17   3  164
# 3         66  72  353

# %%
titanic_train.Age[titanic_train['Pclass']==1].plot(kind='area')
titanic_train.Age[titanic_train['Pclass']==2].plot(kind='area')
titanic_train.Age[titanic_train['Pclass']==3].plot(kind='area')
plt.legend(['p1','p2','p3'])

# %%
titanic_train.Age[titanic_train['Pclass']==1].plot(kind='kde')
titanic_train.Age[titanic_train['Pclass']==2].plot(kind='kde')
titanic_train.Age[titanic_train['Pclass']==3].plot(kind='kde')
plt.legend(['p1','p2','p3'])

# %%
titanic_train.to_csv('ss.csv',index=False)
